# %% [markdown]
# ### What is Python?
# Now that we know what’s a program, then what’s a programming language? Similar  to how human beings use many languages for communication, programming languages  are the languages that you use to communicate with computers, letting the computer  know how you want it to execute the programs that you have defined. There are many  different programming languages that have been developed in the world. Python is  one of the easiest to understand and learn.
# ![01b1848d-25b5-4251-9a6f-c0b07eb0f809.png](attachment:4bdcbb28-c153-4546-8b0c-7969b5e1564b.png)

# %% [markdown]
# ### Write your first Python program
# As a programming language, Python has about 33 keywords which we will talk more in later lessons. And it has some conventions to follow, this is like the English grammars that you have learned.
# Now let’s write our first Python program. It is very convenient to write Python  code on this web site. First click Playground, that will bring you to a code  editor. Now write below code, then click Execute.

# %%
print("Hello Kids Python")

# %% [markdown]
# You will see "Hello Kids Python" being printed at the Output area.
# Woohoo, congratulations for writing your first line of Python code.  There are a few factors with this single line of code.
# First "print" is a function, which refers to knowing how to do a  specific task. In this case, print will print the information in ()  to your computer screen.
# Secondly a function uses a pair of parentheses to specify inputs to its task, the content inside the parenthesis pair is called an argument.
# Lastly, as a common English phrase, "Hello Kids Python!" is called  a string in Python. It needs to be included inside a pair of  single quotes (') or double quotes ("), which I will talk about  more in our next lesson.
# Here I’d like to end today's lesson by leaving a simple homework assignment for you. Please use the Playground on kidspython.com to change your code so it will print:

# %%
print("Hello World")
